# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Laptop_price.csv")

# %%
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 54.8+ KB
# None

# %%
print(df['Brand'].unique())
# Out:
# ['Asus' 'Acer' 'Lenovo' 'HP' 'Dell']

# %%
print(df.isnull().sum())
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
print(df.isna().sum())
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
numeric_df = df.select_dtypes(include = 'number')

# %%
numeric_df
# Out:
#      Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0           3.830296        16               512    11.185147  2.641094
# 1           2.912833         4              1000    11.311372  3.260012
# 2           3.241627         4               256    11.853023  2.029061
# 3           3.806248        16               512    12.280360  4.573865
# 4           3.268097        32              1000    14.990877  4.193472
# ..               ...       ...               ...          ...       ...
# 995         3.343584         4              1000    12.587095  3.162399
# 996         2.780555         8               256    12.679356  3.750265
# 997         3.200569         4               512    12.666315  3.392612
# 998         1.604182         8               256    11.215581  3.857613
# 999         1.711980         4               256    16.561498  3.440883
#
#             Price
# 0    17395.093065
# 1    31607.605919
# 2     9291.023542
# 3    17436.728334
# ...

# %%
numeric_df.corr()
# Out:
#                   Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# Processor_Speed          1.000000  0.021391         -0.067576    -0.013425
# RAM_Size                 0.021391  1.000000          0.002111    -0.036002
# Storage_Capacity        -0.067576  0.002111          1.000000    -0.027560
# Screen_Size             -0.013425 -0.036002         -0.027560     1.000000
# Weight                  -0.054603 -0.025382          0.041335     0.021995
# Price                   -0.050737  0.061237          0.997908    -0.026740
#
#                     Weight     Price
# Processor_Speed  -0.054603 -0.050737
# RAM_Size         -0.025382  0.061237
# Storage_Capacity  0.041335  0.997908
# Screen_Size       0.021995 -0.026740
# Weight            1.000000  0.038417
# Price             0.038417  1.000000

# %%
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
brand_price_m = df.groupby('Brand')['Price'].mean().sort_values(ascending=False).plot(kind = "bar")

plt.title('Average Prices by Brands')
plt.ylabel('Average Prices ($)')
plt.ylabel('Average Prices ($)')
plt.xlabel('Brands')

for i in brand_price_m.patches:
    brand_price_m.annotate(f'{i.get_height():.2f}', 
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                xytext=(0, 0), 
                textcoords='offset points', 
                ha='center', va='bottom')
plt.show()

# %%
brand_price_m
# Out:
# Brand
# Acer      19984.613620
# Lenovo    19974.929725
# Asus      19854.238277
# HP        19369.762930
# Dell      18866.009978
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
ram_brand_c = df.groupby(['RAM_Size','Brand']).size().reset_index(name='count')

# %%
ram_brand_c
# Out:
#     RAM_Size   Brand  count
# 0          4    Acer     50
# 1          4    Asus     47
# 2          4    Dell     48
# 3          4      HP     59
# 4          4  Lenovo     39
# 5          8    Acer     48
# 6          8    Asus     66
# 7          8    Dell     43
# 8          8      HP     38
# 9          8  Lenovo     51
# 10        16    Acer     47
# 11        16    Asus     47
# 12        16    Dell     52
# 13        16      HP     49
# 14        16  Lenovo     42
# 15        32    Acer     59
# 16        32    Asus     46
# 17        32    Dell     67
# 18        32      HP     44
# 19        32  Lenovo     58

# %%
brand_counts = df['Brand'].value_counts().sort_values(ascending=False).plot(kind = "pie")
plt.title("Brand Distribution of Data")
plt.ylabel("")
plt.show()

# %%
brand_counts
# Out:
# Brand
# Dell      210
# Asus      206
# Acer      204
# Lenovo    190
# HP        190
# Name: count, dtype: int64

# %%
df
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
#        'Screen_Size', 'Weight', 'Price'],
#       dtype='object')

# %%
y = df ["Price"]
x = df[["Processor_Speed","RAM_Size", "Storage_Capacity"]]

# %%
x
# Out:
#      Processor_Speed  RAM_Size  Storage_Capacity
# 0           3.830296        16               512
# 1           2.912833         4              1000
# 2           3.241627         4               256
# 3           3.806248        16               512
# 4           3.268097        32              1000
# ..               ...       ...               ...
# 995         3.343584         4              1000
# 996         2.780555         8               256
# 997         3.200569         4               512
# 998         1.604182         8               256
# 999         1.711980         4               256
#
# [1000 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
len(X_train)
# Out:
# 800

# %%
len(y_train)
# Out:
# 800

# %%
len(X_test)
# Out:
# 200

# %%
len(y_test)
# Out:
# 200

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfmodel = RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_gridrfr = {"max_depth":[2,5,10,15,20,25],
                 "max_features" : ["auto","log2"],
                 "n_estimators" : [2,4,6,8,10,12]}

# %%
gridrfr = GridSearchCV(rfmodel,param_gridrfr)

# %%
gridrfr.fit(X_train,y_train)
# Out:
# C:\Users\HP EliteBook 445 G8\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 180 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP EliteBook 445 G8\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP EliteBook 445 G8\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
# ...

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 25, 'max_features': 'log2', 'n_estimators': 12}

# %%
predictions =gridrfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 381.9659281316879

# %%
price_desc = df["Price"].describe()

# %%
price_desc
# Out:
# count     1000.000000
# mean     19604.187963
# std       9406.064880
# min       8570.012950
# 25%      10114.012948
# 50%      17287.241878
# 75%      31566.214754
# max      33503.935037
# Name: Price, dtype: float64

# %%
x.columns
# Out:
# Index(['Processor_Speed', 'RAM_Size', 'Storage_Capacity'], dtype='object')

# %%
gridrfr
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [2, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [2, 4, 6, 8, 10, 12]})

# %%
import joblib

joblib.dump(gridrfr, "rf_model.pkl")
# Out:
# ['rf_model.pkl']
